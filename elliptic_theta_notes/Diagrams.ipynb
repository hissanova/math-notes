# %% [markdown]
# # Ellipse
# Canonical form:
# $$ \frac{x^{2}}{a^{2}} +\frac{y^{2}}{b^{2}}=1 \quad with \; a \ge b.$$
# parametric form:
# $$\mathbf{p} =\left(
# \begin{array}{c}
#  x \\
#  y
# \end{array} \right)
# =\left(
# \begin{array}{c}
#  a \sin{\varphi} \\
#  b \cos{\varphi}
# \end{array} \right)
# \;, where \; 0 \le \varphi < 2 \pi
# $$

# %%
var('t')

color = 'black'

a = 1.5
b = 1
angle = 0.5 

g = Graphics()

g += parametric_plot([a * sin(t), b * cos(t)], [t, 0, 2 * pi], color=color)
g += parametric_plot([a * sin(t), b * cos(t)], [t, 0, angle ], color=color, thickness=3)
g += point([a * sin(angle), b * cos(angle)], size=40, color=color)
g += line([[0, 0], [a * sin(angle), b * cos(angle)]], color=color)

text_pos = 0.1
g += text('$\\textbf{p}$', [a * sin(angle) + text_pos , b * cos(angle) + text_pos], color=color, fontsize='x-large')
g += text('$s$', [a * sin(angle/2.5) + text_pos , b * cos(angle/2.5) + text_pos], color=color, fontsize='x-large')
g.axes_labels(['$x$', '$y$'])
g.matplotlib(ticks=[[],[]])
g.show(ticks=[[],[]], figsize=[5,5])
g.save("ellipse_generic.png", ticks=[[],[]], figsize=[5,5])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-8604d23e2519> in <module>()
#      19 g.axes_labels(['$x$', '$y$'])
#      20 g.matplotlib(ticks=[[],[]])
# ---> 21 g.show(ticks=[[],[]], figsize=[Integer(5),Integer(5)])
#      22 g.save("ellipse_generic.png", ticks=[[],[]], figsize=[Integer(5),Integer(5)])
#
# /home/hisanobu_nakamura/SageMath/local/lib/python2.7/site-packages/sage/misc/decorators.pyc in wrapper(*args, **kwds)
#     481             kwds[self.name + "options"] = suboptions
#     482
# --> 483             return func(*args, **kwds)
#     484
#     485         #Add the options specified by @options to the signature of the wrapped
#
# /home/hisanobu_nakamura/SageMath/local/lib/python2.7/site-packages/sage/plot/graphics.pyc in show(self, **kwds)
#    1985         from sage.repl.rich_output import get_display_manager
# ...
